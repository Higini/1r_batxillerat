# %% [markdown]
# <a href="https://colab.research.google.com/github/Higini/1r_batxillerat/blob/main/Tema_03_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strings en `Python`

# %% [markdown]
# ## Variable string
#
# **String.** És una cadena ordenada de caracters.
#
# Una variable de tipus string és aquella que guarda un string. La manera de declarar una variable de tipus string, `str` en `Python` és envoltar el contingut el contenido entre cometes dobles `" "`, o bé entre cometes simples `' ' `.

# %%
s1 = "Això és un sting entre cometes dobles"
type(s1)
# Out:
# str

# %%
s2 = 'Això és un sting entre cometes dobles'
type(s2)
# Out:
# str

# %% [markdown]
# ##String literals##
#
# Alguns caràcters han de ser tractats de manera especial. Els strings literals més utilitzats es mostren a la següent taula.
#
# Codi | Significat |
# --- | --- |
# `\\` | Backslash, `\`|
# `\'` | Cometa simple, `'`|
# `\"` | Cometa doble, `"`|
# `\n` | Salt de línia|
# `\t` | Tabulació horitzontal|
#
# Per ampliar la informació sobre els strings literals cliqueu sobre l'enllaç: [documentació Strings Literals](https://docs.python.org/3.7/reference/lexical_analysis.html#string-and-bytes-literals).

# %% [markdown]
# ---
# Exemple 1
#
# Imaginem que volem guardar en una variable el següent string:
#
# `El Pep va dir: "m'agrada programar"`
#
# Com ho hem de fer? Necessitem strings literals --> `\'`
#
# ---

# %%
s2 = 'El Pep va dir: "m\'agrada programar"'
s2
# Out:
# 'El Pep va dir: "m\'agrada programar"'

# %% [markdown]
# **Observació**
# Aparentment no funciona, però una cosa és el contingut de la variable i un altre el que podem veure per pantalla. Si apliquem la funció print() es mostra correctament.

# %%
print(s2)
# Out:
# El Pep va dir: "m'agrada programar"

# %% [markdown]
# ---
# Exemple 2
# Si volem guardar en una variable el següent text i que conservi el salt de línia,
#
# `Hola nois/es,`
#
# `Com esteu?`
#
# La forma de fer-ho és la següent
#
# ---

# %%
s1 = 'Hola nois/es,\nCom esteu?'
s1
# Out:
# 'Hola nois/es,\nCom esteu?'

# %%
print(s1)
# Out:
# Hola nois/es,
# Com esteu?

# %% [markdown]
# ##Concatenació d'Strings##
# La concatenació és una operació que uneix dos o més strings en un únic string suma dels altres dos.
#
# En `Python`, per concatenar dos variables de tipus string fem servir la funció `+`.

# %%
s1 = 'Hola, '
s2 = 'Esteve'
s1 + s2
# Out:
# 'Hola, Esteve'

# %% [markdown]
# **Observacions**
# - Hem de dexar un espai en blanc al final de l'string s1 o al principi de l'string s2 per tal de no tenir enganxats els dos strings.
# - El nombre d'espais en blanc es conserven

# %%
s1 = 'Hola,'
s2 = '            Esteve'
s1 + s2
# Out:
# 'Hola,            Esteve'

# %% [markdown]
# ##Repetir strings##
# En `Python`, per repetir una variable de tipus string utilitzem la funció `*`. L'ordre dels factors no  altera el producte i és equivalent a escriure `num_repeticions * variable_str` com `variable_str * num__repeticions`.

# %%
'Papa, Hem arribat? ' * 5
# Out:
# 'Papa, Hem arribat? Papa, Hem arribat? Papa, Hem arribat? Papa, Hem arribat? Papa, Hem arribat? '

# %% [markdown]
# ## Informació per pantalla `print()`##
#
# La función `print()` serveix, entre altres coses, per mostrar strings per pantalla.
#
# **Observació**
# Amb la funció `print()`no es visualitzen les cometes de l'string

# %%
s1 = "Hola Món"
s1
# Out:
# 'Hola Món'

# %%
print(s1)
# Out:
# Hola Món

# %%
x1 = 3.6
print(x1)
# Out:
# 3.6

# %% [markdown]
# També podem concatenar strings amb la función`+`, combinant-la juntament amb la funció `print()`

# %%
nom = 'Esteve'
print('Bon dia, ' + nom + '!')
# Out:
# Bon dia, Esteve!

# %% [markdown]
# Multiplicar amb print()

# %%
print(3 * 'Hola ')
# Out:
# Hola Hola Hola

# %% [markdown]
# Altres paràmetres de la funció `print()`

# %%
missatge_1 = 'Hola'
missatge_2 = 'Esteve'
print(missatge_1, missatge_2)
print(missatge_1, missatge_2, sep = '|')
print(missatge_1, missatge_2, end = '!!')
# Out:
# Hola Esteve
# Hola|Esteve
# Hola Esteve!!

# %% [markdown]
# ##Altres formes de concatenar strings
# ||
# -|-|
# `str()`: pot concatenar strings i variables de qualsevol tipus dintre d'un `print()`
# .`format()`: Concatena strings dintre d'un `print()`
# `f'{}'`: Concatena strings
#
# * El mètode `format()` indica amb claus, `{}`, el lloc on volem situar el resultat de les variables. A continuació dintre dels paréntesis del mètode `.format()` s'indiquen les variables amb el seu respectiu ordre.
# * La sintaxis per formatejar cadenes literals dels "f-strings" és la següent f"Aquesta és una f-string {nom_var} y {nom_var}"

# %%
# Concatenar amb str()
nom = "Toni"
edat = 45
print('El ' + nom + ' té ' + str(edat) + ' anys')
# Out:
# El Toni té 45 anys

# %%
# mètode format
nom = 'Xavi'
edat = 54
print('El {} té {} anys'.format(nom, edat))
# Out:
# El Xavi té 54 anys

# %%
# f-string
print(f"Hola, em dic {'Pep'} i tinc {42} anys")

# %% [markdown]
# Formatejant cadenes

# %%
alçada = 1234
f'{alçada:10d}' # 10 espais incloent-hi els que corresponen als dígits 1234
# Out:
# '      1234'

# %%
f'{alçada:010d}'
# Out:
# '0000001234'

# %% [markdown]
# Donar format a altres bases: binari, octal i hexadecimal

# %%
valor = 0b111 # passar de codi binari a decimal amb '0b' davant del codi binari
f'{valor}'
# Out:
# '7'

# %%
f'{valor:b}' # De decimal a binari
# Out:
# '111'

# %%
valor = 0o111  # Passar de codi octal a decimal --> Afegir '0o' davant del valor
f'{valor}'
# Out:
# '73'

# %%
f'{valor:o}' # De decimal a octal
# Out:
# '111'

# %%
valor = 0x1a # Passar d'hexadecimal a decimal
f'{valor}'
# Out:
# '26'

# %%
f'{valor:x}'
# Out:
# '1a'

# %% [markdown]
# Donar format a valors flotants

# %%
pi = 3.14159265
print(f'pi:f') # 6 decimals per defecte
print(f'{pi:.3f}') # 3 decimals --> .3f
print(f'{pi:10f}') # 8 espais inclosos els dels dígits del nombre pi(8)
print(f'{pi:10.3f}')
print(f'{pi:010.3f}')
print(f'{pi:e}')
# Out:
# pi:f
# 3.142
#   3.141593
#      3.142
# 000003.142
# 3.141593e+00

# %% [markdown]
# ##Llegir informació per teclat `input()`
# La funció `input()` llegeix la informació per teclat
#
# **Observació**
# `input()`sempre torna un objecte string (str)

# %%
nom = input('Com et dius? ')
edat = input('Quina és la teva edat? ')
print(f'El tipus de dades de la variable nom és {type(nom)} i la variable edat és de tipus {type(edat)}')
# Out:
# Com et dius? Pep
# Quina és la teva edat? 34
# El tipus de dades de la variable nom és <class 'str'> i la variable edat és de tipus <class 'str'>

# %% [markdown]
# ##Obtenir un caràcter d'un string##
#
# Els caracters d'un string tenen un índex. Per veure un caràcter dintre d'una cadena de text és necessari especificar l'índex entre claudàtors. A continuació es mostra com indicar el número d'índex.
#
# ---
# [0] |[1] |[2] |[3] |[4] |[5] |
# ---|---|---|---|---|---|
# P|y|t|h|o|n|
# [-6]|[-5] |[-4] |[-3] |[-2] |[-1]
#
# ---
#
# **Observacions**
#
# - L'indexat d'una cadena de text sempre começa per 0 i acaba en una unitat menys la longitud de la cadena.
# - Les cadenes de ext són inmutables.

# %%
variable = 'Python'

# %%
variable[0]
# Out:
# 'P'

# %%
variable[-1]
# Out:
# 'n'

# %%
variable[-6]
# Out:
# 'P'

# %% [markdown]
# * La inmutabilitat de les cadenes de text fa que el codi següent doni un error perquè s'intenta modificar un caràcter.
#
# * Existeixen maneres de modificar una cadena de text però realment no estem trasnformant l'original sino el que fem és crear un nou objecte amb les modificacions.

# %%
string = 'cadena'
string[0] = 'C'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-7177b80ddb18> in <module>
#       1 string = 'cadena'
# ----> 2 string[0] = 'C'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ##Trossejar cadenes (slice)##
# * `[:]` Extreu la seqüència sencera del principi fins al final.
# * `[start:]` Extreu començant pel final de la cadena.
# * `[:end]` Extreu des del començament de la cadena fins end menys 1.
# * `[start:end]` Extreu a partir d'start fins end menys 1.
# * `[start:end:step]`Extreu a partir d'start fins end menys 1 fent salts de tamany step.

# %%
frase = 'Hola companys'
print(frase[:])
print(frase[5:])
print(frase[:4])
print(frase[5:13])
print(frase[::2])
# Out:
# Hola companys
# companys
# Hola
# companys
# Hl opns

# %% [markdown]
# ##Longitut d'una cadena
# La funció `len()`mostra la longitut de l'string o de l'estructura de dades

# %%
frase = 'cosa'
len(frase)
# Out:
# 4

# %% [markdown]
# Si volem saber si una paraula pertany a una frase

# %%
frase = 'El cel de color blau'
'color' in frase
# Out:
# True

# %%
codi = 'A3456pO0jh5'
'j' in codi
# Out:
# True

# %%
'j' not in codi
# Out:
# False

# %% [markdown]
# ## Funció divisió de cadenes
# La funció `split()`divideix cadenes per un separador.
#
# **Observacions**
#
# Divisió de cadenes mitjançant separadors
# * Si no s'especifica un separador, `split()`utilitza per defecte qualsevol seqüència d'espais en blanc, tabuladors i salts de línia.
# * El tipus que torna és una llista

# %%
frase = 'Estic programant amb Python'
frase.split()
# Out:
# ['Estic', 'programant', 'amb', 'Python']

# %%
eines = 'martell, trepant, tornavís'
print(eines.split(','))
print(type(eines))
# Out:
# ['martell', ' trepant', ' tornavís']
# <class 'str'>

# %% [markdown]
# ##Funcions de neteja de cadenes
# ||
# -|-|
# .`strip()`: Elimina caracters al principi i al final d'un string
# `.lstrip()`: Elimina caràcters a l'esquerre de l'estring
# `.rstrip()`: Elimina cràcters a la dreta de l'string
#
# **Observació**
#
# Si no s'especifica els caracters a eliminar, la funció fa servir per defecte qualsevol combinació d'espais en blanc, salts de línia `\n`i tabuladors `\t`.

# %%
serial_number = '\n\t \n 48374983274832 \n\n\t \t \n'
serial_number.strip()
# Out:
# '48374983274832'

# %%
serial_number.lstrip()
# Out:
# '48374983274832 \n\n\t \t \n'

# %%
serial_number.rstrip()
# Out:
# '\n\t \n 48374983274832'

# %%
serial_number.strip( '\n' )
# Out:
# '\t \n 48374983274832 \n\n\t \t '

# %% [markdown]
# ##Funcions de cerca
#
# ||
# -|-|
# .startswith(): Comença per la subcadena
# .endswith(): Acaba per la subcadena
# .find(): Troba la primera coincidència de la subcadena
# .index(): Troba la primera coincidència de la subcadena
#
# **Observació**
#
# La diferència entre `find()`i `index()`es troba en el moment de que no existeixi la subcadena. `find()`donarà un errro i `find()`retorna un "-1".

# %%
frase = 'Pensament computacional i Python'
frase.startswith('Pensament')
# Out:
# True

# %%
frase.endswith('casa')
# Out:
# False

# %%
frase.find('yo')
# Out:
# -1

# %%
frase.index('i')
# Out:
# 18

# %% [markdown]
# ##Altres funcions strings
# ||
# -|-|
# .count(): Nombre de vegades que apareix una subcadena
# .replace(): Substitueix una subcadena
# .capitalize(): Frase comença en majúscula
# .title(): Cadena en forma de títol
# .lower(): tota la frase en minúscules
# .upper(): tota la frase en majúscules
# .swapcase(): Intercanvi de majúscules i minúscules

# %%
frase = "m'agrada moltíssim l'assignatura de programació"
frase.count('s')
# Out:
# 4

# %%
frase.replace('moltíssim','molt poc')
# Out:
# "m'agrada molt poc l'assignatura de programació"

# %%
frase.capitalize()
# Out:
# "M'agrada moltíssim l'assignatura de programació"

# %%
frase.title()
# Out:
# "M'Agrada Moltíssim L'Assignatura De Programació"

# %%
frase.lower()
# Out:
# "m'agrada moltíssim l'assignatura de programació"

# %%
frase.upper()
# Out:
# "M'AGRADA MOLTÍSSIM L'ASSIGNATURA DE PROGRAMACIÓ"

# %%
string = ' Institut Matadepera'
string.swapcase()
# Out:
# ' iNSTITUT mATADEPERA'

# %% [markdown]
# ##Funcions string que retornen un valor booleà
# ||
# -|-|
# .isalnum(): Conté només lletres i nombres?
# .isnumeric(): Conté només nombres?
# .isalpha(): Conté només lletres?
# .isupper(): Tota la cadena conté majúscules?
# .islower(): Tota la cadena conté minúscules?
# .istitle(): La cadena és un títol?

# %%
'456AR5'.isalnum()
# Out:
# True

# %%
'123'.isnumeric()
# Out:
# True

# %%
'pep@gmail.com'.isalpha()
# Out:
# False

# %%
'TONI'.isupper()
# Out:
# True

# %%
'Tecnologia'.islower()
# Out:
# False

# %%
'La casa de paper'.istitle()
# Out:
# False

# %% [markdown]
# ##Funció `dir()`
# Inspecciona l'objecte i podem veure tots els mètodes, variables, etc.

# %% [markdown]
# ##Codi Unicode
# `Python` treballa per defecte amb [Unicode](https://unicode-table.com/en/1F680/)
# * La funció `chr()`permet representar un caràcter a partir del seu codi
# * La funció `ord()`permet obtenir el codi (decimal) d'un caràcter a partir de la seva representació
# * El modificador `\N` permet representar un caràcter a partir del seu nom
#
# **Observació**
#
# Per passar d'hexadecimal a decimal `Python`afegeix `0x`davant del nombre hexadecimal

# %%
codi_coet = 0x1F680
imatge_coet = chr(codi_coet)
print(imatge_coet)
# Out:
# 🚀

# %%
codi_decimal = ord(imatge_coet)
codi_hexadecimal = hex(codi_decimal)
print(codi_hexadecimal)
# Out:
# 0x1f680

# %%
print('\N{ROCKET}')
# Out:
# 🚀

# %%
paraula = 'casa'
dir(paraula)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...
